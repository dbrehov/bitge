# %%
# %%capture
# Зависимости для Linux/Chromium
# !apt-get update
# !apt-get install -y \
    libnss3 libatk1.0-0 libatk-bridge2.0-0 libcups2 \
    libxkbcommon0 libxdamage1 libxcomposite1 libxrandr2 \
    libxfixes3 libxext6 libx11-6 libglib2.0-0 libpango-1.0-0 \
    libcairo2 libasound2 libatk1.0-data fonts-liberation wget xvfb

# Установка Node.js 22
# !curl -fsSL https://deb.nodesource.com/setup_22.x | sudo -E bash -
# !sudo apt-get install -y nodejs

# TypeScript и ts-node
# !npm install -g typescript ts-node

# Установка Playwright и браузеров
# !npm install playwright
# !npx playwright install chromium

# %%
# %%capture
repo_name = "bitge"
# !ls
repo_url = f"https://github.com/dbrehov/{repo_name}.git"
# !git clone {repo_url}
# %cd {repo_name}
# !ls
# !npm i

# %%
# %%capture
# !git pull

# %%
# !xvfb-run -s "-screen 0 1920x1080x24" npx ts-node src/run.ts
# Out:
# ⠙
# ===== bcb64b7586b13b57a191 =====
# NOT_FOUND
#
# ===== b0b34c718aba315fa096 =====
# +16.86%
#
# ===== bab747728cb7315ea69c =====
# +88.95%
#
# ===== bebc4a7389b5395fa19d =====
# +59.91%
#
# ===== b9b04a7586b43853a69d =====
# +11.24%
#
# ===== bcb14a718bbb385ea494 =====
# +37.94%
#
# ===== b0b04f738ab13e51a595 =====
# +4.17%
#
# ===== bbb6467287b63a56a49c =====
# +84.85%
#
# ===== b1b44b708db13957a190 =====
# +25.97%
#
# ===== bcbc4f758ab73f56a795 =====
# +3.25%
#
# ===== bdbd4f758fb1395ea692 =====
# +9.76%
#
# ===== bab24e7388b53056ad95 =====
# +5.97%
#
# ===== b0b04d7088b43057ad95 =====
# +200.57%
# Файл отправлен в Telegram (из памяти)
# ⠙
